# %%
import os
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
CALIBRATION_FOLDER = '../camera_cal'
FILE_EXAMPLE = os.path.join(CALIBRATION_FOLDER, 'calibration1.jpg')
os.listdir(CALIBRATION_FOLDER)
# Out:
# ['calibration17.jpg',
#  'calibration3.jpg',
#  'calibration4.jpg',
#  'calibration9.jpg',
#  'calibration2.jpg',
#  'calibration8.jpg',
#  'calibration14.jpg',
#  'calibration1.jpg',
#  'calibration5.jpg',
#  'calibration19.jpg',
#  'calibration11.jpg',
#  'calibration16.jpg',
#  'calibration12.jpg',
#  'calibration10.jpg',
#  'calibration13.jpg',
#  'calibration6.jpg',
#  'calibration7.jpg',
#  'calibration18.jpg',
#  'calibration20.jpg',
#  'calibration15.jpg']

# %%
img = cv2.imread(FILE_EXAMPLE)
plt.imshow(img)
